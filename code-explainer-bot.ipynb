# %% [markdown]
# # Code Error Explainer
#
# While the earlier project (03a) contained a bot explaining code snippets, in this project I will create a bot explaining code errors.
#
# So the intent is to have a teaching assistant explaining Python errors.
#
# Scope:
# - Explain what an error means
# - Explain why it happens
# - Suggest how to fix it conceptually
#
# Explicitly out of scope:
# - Generating runnable code
# - Providing full solutions
# - Rewriting code snippets

# %%
# Imports

from google import genai
from dotenv import load_dotenv
import os

# %%
# Load API key
load_dotenv()
API_KEY = os.getenv("GOOGLE_API_KEY")

if not API_KEY:
    raise ValueError("GOOGLE_API_KEY not found in environment variables")

# Initialize client
client = genai.Client(api_key=API_KEY)

# %%
# Audience mapping
audience_levels = {
    "1": "beginner",
    "2": "intermediate",
    "3": "developer"
}

audience_descriptions = {
    "1": "Explains in simple, plain language with analogies. Assumes no prior Python knowledge.",
    "2": "Uses some technical terms, assumes familiarity with Python basics.",
    "3": "Concise, technical, assumes programming experience and understanding of concepts."
}

print("Audience options:")
for num, desc in audience_descriptions.items():
    print(f"{num} = {audience_levels[num]}: {desc}")
# Out:
# Audience options:
# 1 = beginner: Explains in simple, plain language with analogies. Assumes no prior Python knowledge.
# 2 = intermediate: Uses some technical terms, assumes familiarity with Python basics.
# 3 = developer: Concise, technical, assumes programming experience and understanding of concepts.

# %% [markdown]
# This will be the prompt:
#
# ```
# You are a Python teaching assistant.
#
# A student ran the following Python code and received an error.
#
# Your task:
# - Explain what the error means
# - Explain why it happened
# - Explain how the student can fix it conceptually
#
# Constraints (must follow):
# - Do NOT provide any runnable code
# - Do NOT rewrite the code
# - Do NOT show full examples
# - Do NOT include code blocks or syntax
#
# Adapt your explanation to the student's level: {audience}
#
# Code & Error:
# {code_and_error}
# ```

# %%
# Prompt
PROMPT_TEMPLATE = """
You are a Python teaching assistant.

A student ran the following Python code and received an error.

Your task:
- Explain what the error means
- Explain why it happened
- Explain how the student can fix it conceptually

Constraints (must follow):
- Do NOT provide any runnable code
- Do NOT rewrite the code
- Do NOT show full examples
- Do NOT include code blocks or syntax

Adapt your explanation to the student's level: {audience}

Code & Error:
{code_and_error}
"""

# %%
# LLM call function
def explain_error(code_and_error: str, audience: str) -> str:
    prompt = PROMPT_TEMPLATE.format(
        code_and_error=code_and_error,
        audience=audience
    )

    # Model can be revised when required - had to do it mid exercise as the one indicated resource exhausted
    response = client.models.generate_content(
        model="models/gemini-2.5-flash-lite",
        # model="models/gemini-2.5-flash",
        contents=prompt
    )

    return response.text

# %%
# Leak detection - look for code patterns or keywords
# to check that the output did not break the rules of providing full code iso only the concept to fix it
def contains_code_leak(text: str) -> bool:
    forbidden_patterns = [
        "```",
        "def ",
        "import ",
        "="
    ]
    return any(pat in text for pat in forbidden_patterns)

# %%
# One-run interactive bot with retry on leak detection
def run_code_explainer_bot_once(max_retries: int = 5):
    print("\nWelcome to Python Error Explainer Bot!")
    print("Type 'quit' or 'exit' at any prompt to stop the bot.\n")
    
    # Step 1 — get combined input
    user_input = input(
        "Paste your code & error traceback here:\n"
    )
    if user_input.lower() in {"quit", "exit"}:
        print("Exiting bot... Goodbye!")
        return False

    # Step 2 — choose audience by number
    print("\nChoose audience level (type the number, or 'quit' to exit):")
    for num, desc in audience_descriptions.items():
        print(f"{num} = {audience_levels[num]}: {desc}")

    user_choice = ""
    while user_choice not in audience_levels:
        user_choice = input("Audience number: ").strip()
        if user_choice.lower() in {"quit", "exit"}:
            print("Exiting bot... Goodbye!")
            return False
        if user_choice not in audience_levels:
            print("Invalid choice. Please enter 1, 2, or 3.")

    user_audience = audience_levels[user_choice]

    # Step 3 — show input
    print("\n--- User Input ---")
    print(user_input)
    print("Audience level:", user_audience)

    # Step 4 — generate explanation with retry if code leak detected
    for attempt in range(1, max_retries + 1):
        explanation = explain_error(user_input, user_audience)
        if contains_code_leak(explanation):
            print(f"\n⚠️ Attempt {attempt}: Generated explanation contained code. Retrying...")
        else:
            print("\n--- Explanation ---")
            print(explanation)
            break
    else:
        print("\n⚠️ Could not generate explanation without code after several retries.")
        print("Please try again or simplify your input.")

    return True

# %%
# Loop for optional repeated runs
while True:
    continue_bot = run_code_explainer_bot_once()
    if not continue_bot:
        break

    again = input("\nDo you want to run another explanation? (y/n): ").lower()
    if again not in {"y", "yes"}:
        print("Goodbye! Thanks for using the Python Error Explainer Bot.")
        break
# Out:
# Welcome to Python Error Explainer Bot!
# Type 'quit' or 'exit' at any prompt to stop the bot.
#
#
# Choose audience level (type the number, or 'quit' to exit):
# 1 = beginner: Explains in simple, plain language with analogies. Assumes no prior Python knowledge.
# 2 = intermediate: Uses some technical terms, assumes familiarity with Python basics.
# 3 = developer: Concise, technical, assumes programming experience and understanding of concepts.
#
# --- User Input ---
# --------------------------------------------------------------------------- ClientError                               Traceback (most recent call last) Cell In[18], line 62      59 print("\n--- User Input ---")      60 print(case["input"]) ---> 62 explanation = explain_error(case["input"], case["audience"])      64 print(f"\n--- Explanation ({case['audience']}) ---")      65 print(explanation)  Cell In[14], line 9       3 prompt = PROMPT_TEMPLATE.format(       4     code_and_error=code_and_error,       5     audience=audience       6 )       8 # Model can be revised when required - had to do it mid exercise as the one indicated resource exhausted ----> 9 response = client.models.generate_content(      10     # model="models/gemini-2.5-flash-lite",      11     model="models/gemini-2.5-flash",      12     contents=prompt      13 )      15 return response.text  File ~/Desktop/BeCode_Projects/code-explainer-bot/.venv/lib/python3.13/site-packages/google/genai/models.py:5215, in Models.generate_content(self, model, contents, config)    5213 while remaining_remote_calls_afc > 0:    5214   i += 1 ... --> 146   raise ClientError(status_code, response_json, response)     147 elif 500 <= status_code < 600:     148   raise ServerError(status_code, response_json, response)  ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 51.194342344s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}} Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
# Audience level: beginner
#
# --- Explanation ---
# The error you're seeing is called a `ClientError`.
#
# **What it means:**
#
# This error tells you that your code tried to do something, but the service it was trying to connect to (in this case, a Google AI service for generating text) said "no" because you've used up all the resources you're allowed to use for a certain period.
#
# **Why it happened:**
#
# The specific message "RESOURCE_EXHAUSTED" means you've hit a limit on how many times you can ask the AI to generate content. The error message even points out that you've exceeded the "free tier requests" for the `gemini-2.5-flash` model. Think of it like a free trial or a daily limit – once you reach it, you have to wait before you can use it again.
#
# **How to fix it conceptually:**
#
# To fix this, you need to do one of two things:
#
# 1.  **Wait:** The error message suggests retrying later. There's a waiting period mentioned (around 51 seconds). After that time has passed, you should be able to make more requests.
#
# 2.  **Check your plan/billing:** If you plan to use this service more often, you might need to look into upgrading your plan or checking your billing details. This usually involves paying for more usage beyond the free limits.
# Goodbye! Thanks for using the Python Error Explainer Bot.

# %% [markdown]
# ## Reflection on this Code Explainer Bot Exercise
#
# * **Combining inputs efficiently:** Using a single combined input for code and error/traceback simplified the prompt design and user workflow. Originally I had inputs for code and error separately which made it more complicated for the user
#
# * **Prompt engineering matters:** Structuring prompts clearly with instructions on conceptual explanations and avoiding full code solutions improved response quality and reliability.
#
# * **Dynamic parameters and user interaction:** Adding a dynamic choice for audience levels (with numeric codes) made the bot flexible while maintaining a simple interface. Building an optional loop for repeated runs reinforced control over the workflow.
#
# * **Code safety and output handling:** Implementing **code leak detection** demonstrated how to safeguard against unintended code execution or exposure in outputs.
#
# * **Iterative testing and refinement:** Running multiple test cases and observing responses highlighted the iterative nature of working with generative AI. It emphasized debugging prompts, retry strategies, and visual presentation in a notebook environment.
#
# * **Model limitations and switching:** During testing, I noticed that the initially used model eventually failed to respond. Switching to another model, or using retry logic, ensured continuity and better-quality explanations. It reinforced the need to consider model choice, reliability, and fallback strategies when building interactive AI tools.
#
# * **Further Improvements:** I was looking at wrapping of the input/output text, but would rather implement a VSCode extension than having additional code for such.

# %%
# NEW TEST SCENARIOS CELL (audience hardcoded per case) - earlier test cases had separate code & error

test_cases = [
    {
        "name": "NameError",
        "audience": "beginner",
        "input": """---------------------------------------------------------------------------
NameError                               Traceback (most recent call last)
Cell [1], line 1
    print(x)
NameError: name 'x' is not defined"""
    },
    {
        "name": "TypeError",
        "audience": "beginner",
        "input": """---------------------------------------------------------------------------
TypeError                               Traceback (most recent call last)
Cell [2], line 3
    len(5)
TypeError: object of type 'int' has no len()"""
    },
    {
        "name": "IndexError",
        "audience": "intermediate",
        "input": """---------------------------------------------------------------------------
IndexError                               Traceback (most recent call last)
Cell [3], line 2
    lst = [1,2]
    print(lst[5])
IndexError: list index out of range"""
    },
    {
        "name": "ModuleNotFoundError",
        "audience": "intermediate",
        "input": """---------------------------------------------------------------------------
ModuleNotFoundError                       Traceback (most recent call last)
Cell [4], line 1
    import some_nonexistent_module
ModuleNotFoundError: No module named 'some_nonexistent_module'"""
    },
    {
        "name": "ZeroDivisionError",
        "audience": "developer",
        "input": """---------------------------------------------------------------------------
ZeroDivisionError                         Traceback (most recent call last)
Cell [5], line 2
    x = 5/0
ZeroDivisionError: division by zero"""
    }
]

# Run test cases
for case in test_cases:
    print("\n" + "=" * 80)
    print(f"Test Case: {case['name']}")
    print(f"Audience: {case['audience']}")
    print("=" * 80)

    print("\n--- User Input ---")
    print(case["input"])

    explanation = explain_error(case["input"], case["audience"])

    print(f"\n--- Explanation ({case['audience']}) ---")
    print(explanation)
# Out:
# ================================================================================
# Test Case: NameError
# Audience: beginner
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# Cell [1], line 1
#     print(x)
# NameError: name 'x' is not defined
#
# --- Explanation (beginner) ---
# Hello there! Let's figure out what's going on with your Python code.
#
# **What the error means:**
#
# The message `NameError: name 'x' is not defined` is Python telling you that it doesn't know what the name `x` refers to. Think of it like trying to ask someone about a person they've never heard of before. Python needs to be introduced to `x` before it can do anything with it.
#
# **Why it happened:**
#
# In Python, you have to create or "define" a variable before you can use it. This is like giving a name to a box where you'll store some information. In your code, you tried to `print(x)` without ever telling Python what `x` is or what value it should hold. Python looked for a variable named `x` and couldn't find one because it hadn't been created yet.
#
# **How to fix it conceptually:**
#
# To solve this, you need to give `x` a value before you try to `print(x)`. This is called assigning a value to the variable. You can do this by using the assignment operator, which is the equals sign (`=`). You'll want to decide what kind of information you want to store in `x` (like a number or some text) and then assign that information to `x` using the equals sign. Once you've done that, Python will know what `x` is and will be able to print its value for you.
#
# ================================================================================
# Test Case: TypeError
# Audience: beginner
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# Cell [2], line 3
#     len(5)
# TypeError: object of type 'int' has no len()
#
# --- Explanation (beginner) ---
# Hey there! Let's break down this error you're seeing.
#
# **What the error means:**
#
# The message `TypeError: object of type 'int' has no len()` is telling you that you're trying to use a tool that doesn't work with the kind of thing you're giving it. Think of it like trying to use a can opener on a piece of fruit – it's just not designed for that. In programming, `TypeError` means you're trying to do an operation (like getting the length) on a data type (like a whole number) that doesn't support that operation.
#
# **Why it happened:**
#
# The `len()` function in Python is used to find out how many items are inside something that can hold multiple items, like a list of words or a string of characters. It's meant for "collections" of things. A whole number, like `5`, isn't a collection; it's just a single, individual value. Python doesn't know how to count the "items" inside a single number, so it throws this error.
#
# **How to fix it conceptually:**
#
# To fix this, you need to make sure you're only using the `len()` function on things that actually *have* a length. If you want to find the length of something, you should be passing in a data type that is designed to hold multiple items. Think about what you were trying to get the "length" of. If you intended to work with a sequence of characters or a group of items, make sure you're using the correct data type for that purpose before you try to measure its length.
#
# ================================================================================
# Test Case: IndexError
# Audience: intermediate
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# IndexError                               Traceback (most recent call last)
# Cell [3], line 2
#     lst = [1,2]
#     print(lst[5])
# IndexError: list index out of range
#
# --- Explanation (intermediate) ---
# You've encountered an `IndexError`.
#
# This error means you're trying to access an element in a list using an index that doesn't exist within that list's boundaries. Think of a list like a row of mailboxes, each with a specific number (its index). If you try to get mail from mailbox number 10, but there are only mailboxes numbered 0 through 5, you'll get an error.
#
# In your case, the list you created has a certain number of elements. When you try to access an element using `lst[5]`, you're asking for the sixth element (because indexing starts at 0). However, the list doesn't have that many elements. The index you've provided is "out of range" for the available elements in the list.
#
# To fix this, you need to ensure that the index you use to access an element is a valid index for the list. This means the index should be a non-negative integer and less than the total number of items in the list. You can check the length of the list to understand its valid index range.
#
# ================================================================================
# Test Case: ModuleNotFoundError
# Audience: intermediate
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell [4], line 1
#     import some_nonexistent_module
# ModuleNotFoundError: No module named 'some_nonexistent_module'
#
# --- Explanation (intermediate) ---
# Let's break down this `ModuleNotFoundError`.
#
# **What the Error Means**
#
# This error, `ModuleNotFoundError: No module named 'some_nonexistent_module'`, is Python's way of telling you that it couldn't find the specific piece of code (the module) you're trying to bring into your current program. Think of modules as pre-written toolkits or libraries that provide extra functions and capabilities. When you use the `import` statement, you're asking Python to load one of these toolkits so you can use its tools. This error means Python looked for the toolkit you named, but it just wasn't where it expected to find it.
#
# **Why It Happened**
#
# The most common reason for this error is that the module you're trying to import simply isn't installed in your current Python environment. Python only comes with a core set of built-in modules. For most other functionalities (like handling web requests, working with specific data formats, or creating advanced visualizations), you need to install external libraries.
#
# Another possibility, though less likely if you're sure the module exists, is that there might be a typo in the module's name. Python is case-sensitive, so `Some_Module` is different from `some_module`.
#
# Finally, if the module is installed but in a location that Python isn't currently checking, you could also see this error. This is more common in complex setups with multiple Python installations or virtual environments.
#
# **How to Fix It Conceptually**
#
# To resolve this, you need to make the module accessible to your Python interpreter.
#
# The primary way to do this is by **installing the module**. Python has a package manager called `pip` that is designed specifically for this purpose. You would use `pip` to download and install the module from an online repository. Once installed, Python will be able to locate and import it.
#
# If you suspect a typo, you'll need to **verify the correct spelling** of the module you intend to import. Check the documentation or source where you learned about this module to ensure you're using the exact name.
#
# In scenarios with multiple Python installations, you might need to ensure you are using `pip` that corresponds to the Python interpreter running your code. This often involves using `pip` within a specific virtual environment or using a command like `python -m pip install ...` to explicitly tie the installation to the correct Python executable.
#
# ================================================================================
# Test Case: ZeroDivisionError
# Audience: developer
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell [5], line 2
#     x = 5/0
# ZeroDivisionError: division by zero
#
# --- Explanation (developer) ---
# This error, `ZeroDivisionError: division by zero`, is quite literal in its meaning.
#
# It occurred because your code attempted to perform a division operation where the divisor was zero. In mathematics, division by zero is undefined, and Python, like most programming languages, will halt execution and raise this specific error to prevent an unresolvable operation.
#
# To fix this conceptually, you need to ensure that the number you are dividing by is never zero. This might involve adding checks before the division occurs. You could, for instance, examine the value of the divisor to see if it's zero. If it is, you'll need to decide on an alternative course of action, such as skipping the division, providing a default value, or signaling an error condition to the user or another part of your program.
