# %% [markdown]
# # Code Error Explainer
#
# While the earlier project (03a) contained a bot explaining code snippets, in this project I will create a bot explaining code errors.
#
# So the intent is to have a teaching assistant explaining Python errors.
#
# Scope:
# - Explain what an error means
# - Explain why it happens
# - Suggest how to fix it conceptually
#
# Explicitly out of scope:
# - Generating runnable code
# - Providing full solutions
# - Rewriting code snippets

# %%
# Imports

from google import genai
from dotenv import load_dotenv
import os

# %%
# Load API key
load_dotenv()
API_KEY = os.getenv("GOOGLE_API_KEY")

if not API_KEY:
    raise ValueError("GOOGLE_API_KEY not found in environment variables")

# Initialize client
client = genai.Client(api_key=API_KEY)

# %%
# Audience mapping
audience_levels = {
    "1": "beginner",
    "2": "intermediate",
    "3": "developer"
}

audience_descriptions = {
    "1": "Explains in simple, plain language with analogies. Assumes no prior Python knowledge.",
    "2": "Uses some technical terms, assumes familiarity with Python basics.",
    "3": "Concise, technical, assumes programming experience and understanding of concepts."
}

print("Audience options:")
for num, desc in audience_descriptions.items():
    print(f"{num} = {audience_levels[num]}: {desc}")
# Out:
# Audience options:
# 1 = beginner: Explains in simple, plain language with analogies. Assumes no prior Python knowledge.
# 2 = intermediate: Uses some technical terms, assumes familiarity with Python basics.
# 3 = developer: Concise, technical, assumes programming experience and understanding of concepts.

# %% [markdown]
# This will be the prompt:
#
# ```
# You are a Python teaching assistant.
#
# A student ran the following Python code and received an error.
#
# Your task:
# - Explain what the error means
# - Explain why it happened
# - Explain how the student can fix it conceptually
#
# Constraints (must follow):
# - Do NOT provide any runnable code
# - Do NOT rewrite the code
# - Do NOT show full examples
# - Do NOT include code blocks or syntax
#
# Adapt your explanation to the student's level: {audience}
#
# Code & Error:
# {code_and_error}
# ```

# %%
# Prompt
PROMPT_TEMPLATE = """
You are a Python teaching assistant.

A student ran the following Python code and received an error.

Your task:
- Explain what the error means
- Explain why it happened
- Explain how the student can fix it conceptually

Constraints (must follow):
- Do NOT provide any runnable code
- Do NOT rewrite the code
- Do NOT show full examples
- Do NOT include code blocks or syntax

Adapt your explanation to the student's level: {audience}

Code & Error:
{code_and_error}
"""

# %%
# LLM call function
def explain_error(code_and_error: str, audience: str) -> str:
    prompt = PROMPT_TEMPLATE.format(
        code_and_error=code_and_error,
        audience=audience
    )

    # Model can be revised when required - had to do it mid exercise as the one indicated resource exhausted
    response = client.models.generate_content(
        # model="models/gemini-2.5-flash-lite",
        model="models/gemini-2.5-flash",
        contents=prompt
    )

    return response.text

# %%
# Leak detection - look for code patterns or keywords
# to check that the output did not break the rules of providing full code iso only the concept to fix it
def contains_code_leak(text: str) -> bool:
    forbidden_patterns = [
        "```",
        "def ",
        "import ",
        "="
    ]
    return any(pat in text for pat in forbidden_patterns)

# %%
# One-run interactive bot with retry on leak detection
def run_code_explainer_bot_once(max_retries: int = 5):
    print("\nWelcome to Python Error Explainer Bot!")
    print("Type 'quit' or 'exit' at any prompt to stop the bot.\n")
    
    # Step 1 — get combined input
    user_input = input(
        "Paste your code & error traceback here:\n"
    )
    if user_input.lower() in {"quit", "exit"}:
        print("Exiting bot... Goodbye!")
        return False

    # Step 2 — choose audience by number
    print("\nChoose audience level (type the number, or 'quit' to exit):")
    for num, desc in audience_descriptions.items():
        print(f"{num} = {audience_levels[num]}: {desc}")

    user_choice = ""
    while user_choice not in audience_levels:
        user_choice = input("Audience number: ").strip()
        if user_choice.lower() in {"quit", "exit"}:
            print("Exiting bot... Goodbye!")
            return False
        if user_choice not in audience_levels:
            print("Invalid choice. Please enter 1, 2, or 3.")

    user_audience = audience_levels[user_choice]

    # Step 3 — show input
    print("\n--- User Input ---")
    print(user_input)
    print("Audience level:", user_audience)

    # Step 4 — generate explanation with retry if code leak detected
    for attempt in range(1, max_retries + 1):
        explanation = explain_error(user_input, user_audience)
        if contains_code_leak(explanation):
            print(f"\n⚠️ Attempt {attempt}: Generated explanation contained code. Retrying...")
        else:
            print("\n--- Explanation ---")
            print(explanation)
            break
    else:
        print("\n⚠️ Could not generate explanation without code after several retries.")
        print("Please try again or simplify your input.")

    return True

# %%
# Loop for optional repeated runs
while True:
    continue_bot = run_code_explainer_bot_once()
    if not continue_bot:
        break

    again = input("\nDo you want to run another explanation? (y/n): ").lower()
    if again not in {"y", "yes"}:
        print("Goodbye! Thanks for using the Python Error Explainer Bot.")
        break
# Out:
# Welcome to Python Error Explainer Bot!
# Type 'quit' or 'exit' at any prompt to stop the bot.
#
#
# Choose audience level (type the number, or 'quit' to exit):
# 1 = beginner: Explains in simple, plain language with analogies. Assumes no prior Python knowledge.
# 2 = intermediate: Uses some technical terms, assumes familiarity with Python basics.
# 3 = developer: Concise, technical, assumes programming experience and understanding of concepts.
# Invalid choice. Please enter 1, 2, or 3.
# Invalid choice. Please enter 1, 2, or 3.
# Invalid choice. Please enter 1, 2, or 3.
# Exiting bot... Goodbye!

# %% [markdown]
# ## Reflection on this Code Explainer Bot Exercise
#
# * **Combining inputs efficiently:** Using a single combined input for code and error/traceback simplified the prompt design and user workflow. Originally I had inputs for code and error separately which made it more complicated for the user
#
# * **Prompt engineering matters:** Structuring prompts clearly with instructions on conceptual explanations and avoiding full code solutions improved response quality and reliability.
#
# * **Dynamic parameters and user interaction:** Adding a dynamic choice for audience levels (with numeric codes) made the bot flexible while maintaining a simple interface. Building an optional loop for repeated runs reinforced control over the workflow.
#
# * **Code safety and output handling:** Implementing **code leak detection** demonstrated how to safeguard against unintended code execution or exposure in outputs.
#
# * **Iterative testing and refinement:** Running multiple test cases and observing responses highlighted the iterative nature of working with generative AI. It emphasized debugging prompts, retry strategies, and visual presentation in a notebook environment.
#
# * **Model limitations and switching:** During testing, I noticed that the initially used model eventually failed to respond. Switching to another model, or using retry logic, ensured continuity and better-quality explanations. It reinforced the need to consider model choice, reliability, and fallback strategies when building interactive AI tools.
#
# * **Further Improvements:** I was looking at wrapping of the input/output text, but would rather implement a VSCode extension than having additional code for such.

# %%
# NEW TEST SCENARIOS CELL (audience hardcoded per case) - earlier test cases had separate code & error

test_cases = [
    {
        "name": "NameError",
        "audience": "beginner",
        "input": """---------------------------------------------------------------------------
NameError                               Traceback (most recent call last)
Cell [1], line 1
    print(x)
NameError: name 'x' is not defined"""
    },
    {
        "name": "TypeError",
        "audience": "beginner",
        "input": """---------------------------------------------------------------------------
TypeError                               Traceback (most recent call last)
Cell [2], line 3
    len(5)
TypeError: object of type 'int' has no len()"""
    },
    {
        "name": "IndexError",
        "audience": "intermediate",
        "input": """---------------------------------------------------------------------------
IndexError                               Traceback (most recent call last)
Cell [3], line 2
    lst = [1,2]
    print(lst[5])
IndexError: list index out of range"""
    },
    {
        "name": "ModuleNotFoundError",
        "audience": "intermediate",
        "input": """---------------------------------------------------------------------------
ModuleNotFoundError                       Traceback (most recent call last)
Cell [4], line 1
    import some_nonexistent_module
ModuleNotFoundError: No module named 'some_nonexistent_module'"""
    },
    {
        "name": "ZeroDivisionError",
        "audience": "developer",
        "input": """---------------------------------------------------------------------------
ZeroDivisionError                         Traceback (most recent call last)
Cell [5], line 2
    x = 5/0
ZeroDivisionError: division by zero"""
    }
]

# Run test cases
for case in test_cases:
    print("\n" + "=" * 80)
    print(f"Test Case: {case['name']}")
    print(f"Audience: {case['audience']}")
    print("=" * 80)

    print("\n--- User Input ---")
    print(case["input"])

    explanation = explain_error(case["input"], case["audience"])

    print(f"\n--- Explanation ({case['audience']}) ---")
    print(explanation)
# Out:
# ================================================================================
# Test Case: NameError
# Audience: beginner
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# Cell [1], line 1
#     print(x)
# NameError: name 'x' is not defined
#
# --- Explanation (beginner) ---
# Hey there! No worries, this is a very common error when you're just starting out, and it's a great opportunity to understand something fundamental about how Python works.
#
# Let's break down that error message for you:
#
# ### What the error means
#
# The message `NameError: name 'x' is not defined` tells you a couple of things:
#
# *   **NameError**: This means Python encountered a problem related to a "name" it was trying to use. In programming, names are often for things like variables.
# *   **name 'x' is not defined**: This is the specific issue. Python was trying to find something called 'x', but it couldn't find any record of 'x' existing or having been set up yet. It's like trying to refer to someone by name who hasn't been introduced to you.
#
# ### Why it happened
#
# In your code, you have `print(x)`. When Python sees this, its job is to look for whatever 'x' refers to so it can show you its value.
#
# The error happened because, before that line `print(x)` was executed, you didn't tell Python what 'x' *is*. You didn't give 'x' a value, or create it in any way. Python simply doesn't know what 'x' means or what value it should hold.
#
# Think of it like this: you're asking Python to "print the value of x," but you never first said, "Hey Python, let x be equal to 10" or "Let x be equal to 'hello'". So, when Python goes to look for 'x', it comes up empty-handed.
#
# ### How the student can fix it conceptually
#
# To fix this, you need to introduce 'x' to Python *before* you try to use it.
#
# Conceptually, before you can ask Python to do something with a variable (like printing its value, doing math with it, or using it in any other way), you must first perform an action that sets up that variable and gives it an initial value. This act of giving a variable a value for the first time is called "defining" or "initializing" the variable.
#
# So, the fix involves making sure that somewhere in your code, *before* the line where you use 'x', you include a step that gives 'x' a value. This way, when Python gets to the line where you use 'x', it will already know what 'x' refers to and can proceed without confusion.
#
# ================================================================================
# Test Case: TypeError
# Audience: beginner
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# Cell [2], line 3
#     len(5)
# TypeError: object of type 'int' has no len()
#
# --- Explanation (beginner) ---
# Hello there! Don't worry, this is a very common misunderstanding for beginners, and it's a great opportunity to learn about how Python works with different kinds of information. Let's break down that error message.
#
# ### What the error means
#
# The message "TypeError: object of type 'int' has no len()" tells us two main things:
#
# 1.  **"TypeError"**: This means Python encountered a problem because you tried to do an operation with a type of information that isn't suitable for it. Python expects a certain "kind" of data for a specific action, but it received a different "kind" instead.
# 2.  **"object of type 'int' has no len()"**: This specific part explains *what* the type mismatch was.
#     *   An "int" is Python's way of referring to a whole number, like 5, 10, or 100.
#     *   "has no len()" means that whole numbers don't have a built-in way to calculate a "length" using the `len()` function.
#
# So, in simple terms, Python is saying: "I was asked to find the length of a whole number, but whole numbers don't have a concept of length that I can measure with the `len()` tool."
#
# ### Why it happened
#
# The `len()` function in Python is specifically designed to count the number of *items* in something that can be considered a collection or a sequence. Think of it like measuring how many letters are in a word, or how many things are in a list.
#
# *   **Things that have a length**: Words (like "hello" has 5 letters), or collections of different items (like a shopping list with 3 items). These are sequences of multiple individual pieces.
# *   **Things that *don't* have a length (in this context)**: A single whole number, like 5, is just one single, indivisible value. It doesn't have multiple smaller pieces or items to count within itself. It's just... 5. You wouldn't ask "how many items are in the number 5?" because it's just one thing.
#
# You tried to use `len()` on the number 5, which is a single whole number, not a collection or sequence of items. Because a single number doesn't have multiple parts to count, the `len()` function doesn't know what to do with it, leading to the error.
#
# ### How the student can fix it conceptually
#
# To fix this, you need to remember what `len()` is for and provide it with the right kind of information:
#
# 1.  **If you want to find the length of something**: Make sure that "something" is actually a collection of items or a sequence that has a measurable count. For example, if you wanted to know how many characters are in a word, you would give `len()` that word. If you wanted to know how many entries are in a list of names, you would give `len()` that list.
# 2.  **If you weren't trying to find a length at all**: If your goal was something else entirely with the number 5 (like adding it to another number, or multiplying it), then you need to use a different operation or function that is specifically designed for working with numbers. The `len()` function is not the tool for general numeric calculations; it's specialized for counting items in sequences.
#
# In essence, you need to make sure the tool you're using (like `len()`) matches the kind of information you're giving it (like a whole number versus a collection of items).
#
# ================================================================================
# Test Case: IndexError
# Audience: intermediate
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# IndexError                               Traceback (most recent call last)
# Cell [3], line 2
#     lst = [1,2]
#     print(lst[5])
# IndexError: list index out of range
#
# --- Explanation (intermediate) ---
# Hello there! I can definitely help you understand that error.
#
# **What the error means:**
#
# An `IndexError` is a common problem that occurs when you try to access an item in a sequence (like a list) using an index that doesn't exist. The specific message "list index out of range" tells you exactly what went wrong: the number you used to try and retrieve an item from your list was outside the valid set of positions for that list.
#
# **Why it happened:**
#
# In Python, lists are ordered collections, and each item has a unique position identified by an index. These indices always start counting from zero for the very first item. So, for a list containing a certain number of elements, the valid positive indices range from zero up to one less than the total number of elements in the list.
#
# In your specific situation, you created a list that had two items in it. This means the first item could be accessed using index zero, and the second item could be accessed using index one. When you then tried to access the item at index five, Python looked for a fifth position in your two-item list. Since there are only items at positions zero and one, index five simply doesn't exist in that list, leading to the "index out of range" error.
#
# **How the student can fix it conceptually:**
#
# The fundamental fix for this error is to ensure that the index you use to access an item in a list always falls within the valid range of indices for that particular list.
#
# 1.  **Verify the list's size:** Before attempting to retrieve an item, consider how many items are actually in your list.
# 2.  **Adjust the index:** If you intend to access an existing item, make sure the index you're using is between zero (for the first item) and one less than the total number of items in the list.
# 3.  **Consider bounds checks:** If your program dynamically determines indices or if lists might change in size, you might need to include logic to check the list's current size before attempting an access. This ensures you don't try to access a position that doesn't exist.
# 4.  **Review your intent:** Sometimes, an `IndexError` indicates a mismatch between what you expect the list to contain or how large you expect it to be, versus its actual state when the access attempt is made. Double-check your logic leading up to the list access.
#
# ================================================================================
# Test Case: ModuleNotFoundError
# Audience: intermediate
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell [4], line 1
#     import some_nonexistent_module
# ModuleNotFoundError: No module named 'some_nonexistent_module'
#
# --- Explanation (intermediate) ---
# Hello! Let's break down that error you encountered.
#
# ### What the error means
#
# The `ModuleNotFoundError` indicates that when Python tried to execute your `import` statement, it couldn't locate a module with the specified name. Think of a module as a collection of code (functions, classes, variables) stored in a separate file, which you want to bring into your current program to use. When Python gets this particular error, it's essentially saying, "I looked everywhere I know to look for something named that, and I couldn't find it."
#
# ### Why it happened
#
# In your specific situation, the error happened because you attempted to `import some_nonexistent_module`. Python searched its standard locations, your current working directory, and any other places it's configured to look for modules. Since a module named `some_nonexistent_module` likely doesn't exist anywhere—either as a built-in part of Python, a third-party library, or a custom file you created—Python couldn't find it and thus raised this error. It couldn't fulfill the request to load something that doesn't exist by that name.
#
# ### How the student can fix it conceptually
#
# To resolve this, you'll want to consider a few possibilities:
#
# 1.  **Check for Typos:** The most common cause is a simple spelling mistake in the module's name. Double-check that the name you're using in your `import` statement exactly matches the name of the module you intend to use.
# 2.  **Verify Installation:** If you're trying to use a module that isn't part of Python's standard library (often called a third-party library), it might not be installed in your current Python environment. These types of modules usually need to be installed separately before you can import them.
# 3.  **Confirm Custom Module Location:** If `some_nonexistent_module` was meant to be a file you created yourself, ensure that the file exists and is located in a place where Python knows to look. This often means it should be in the same directory as the script you're running, or in a directory that's part of Python's module search path.
# 4.  **Use the Correct Name:** If the name `some_nonexistent_module` was just a placeholder, you'll need to replace it with the actual, correct name of the module you genuinely intend to work with.
#
# ================================================================================
# Test Case: ZeroDivisionError
# Audience: developer
# ================================================================================
#
# --- User Input ---
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell [5], line 2
#     x = 5/0
# ZeroDivisionError: division by zero
#
# --- Explanation (developer) ---
# Hello! Let's break down that error you encountered.
#
# ### What the error means
#
# The `ZeroDivisionError` is Python's way of telling you that you tried to perform an operation where a number was divided by zero. In mathematics, division by zero is undefined, and programming languages reflect this by raising an error because there's no meaningful numerical result they can produce.
#
# ### Why it happened
#
# This error occurred because your code explicitly attempted to divide the number five by zero. The `/` operator signifies division, and when its right-hand operand is zero, Python stops execution and signals this specific error. It's a fundamental mathematical constraint that programming languages must respect.
#
# ### How to fix it conceptually
#
# To prevent this error, the core idea is to ensure that the value you are using as a divisor is never zero *before* the division operation takes place. Here are the conceptual approaches:
#
# 1.  **Implement a Pre-Check:** Before executing any division, you should always verify the value of your divisor. If it evaluates to zero, you would then branch your program's logic to handle that specific case. This might involve assigning a default value, skipping the division entirely, or prompting for different input.
#
# 2.  **Anticipate and Handle:** For situations where the divisor's value might unpredictably become zero (e.g., from user input, data retrieval, or complex calculations), you can incorporate an error handling mechanism. This allows your program to "catch" the `ZeroDivisionError` if it occurs, preventing a crash and allowing you to execute alternative code gracefully, such as logging the issue, returning a special indicator, or informing the user.
